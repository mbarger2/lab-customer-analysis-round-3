# %%
import pandas as pd

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
file1 = pd.read_csv('C:/Users/Matthew/DAclass/Activities/LCAR3/lab-customer-analysis-round-3/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
file2 = pd.read_excel('C:/Users/Matthew/DAclass/Activities/LCAR3/lab-customer-analysis-round-3/files_for_lab/excel_files/marketing_customer_analysis.xlsx')

# %%
file1
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
file2
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
file1.columns == file2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
tfile=pd.concat([file1,file2],axis=0)

# %%
tfile
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
type(tfile)
# Out:
# pandas.core.frame.DataFrame

# %%
tfile.shape
# Out:
# (18268, 24)

# %%
tfile.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             18268.000000  18268.000000          18268.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.779535  30379.073171             34.407026
# min                1898.007675      0.000000             61.000000
# 25%                3993.882994      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.795984  62326.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count             18268.000000                   18268.000000
# mean                 15.097000                      48.064594
# std                  10.072981                      27.905227
# min                   0.000000                       0.000000
# ...

# %%
tfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18268 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       18268 non-null  object
#  1   State                          18268 non-null  object
#  2   Customer Lifetime Value        18268 non-null  float64
#  3   Response                       18268 non-null  object
#  4   Coverage                       18268 non-null  object
#  5   Education                      18268 non-null  object
#  6   Effective To Date              18268 non-null  object
#  7   EmploymentStatus               18268 non-null  object
#  8   Gender                         18268 non-null  object
#  9   Income                         18268 non-null  int64
#  10  Location Code                  18268 non-null  object
#  11  Marital Status                 18268 non-null  object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.hist(tfile['Response'])
plt.show()

# %%
tfile['Sales Channel'].value_counts()
# Out:
# Agent          6954
# Branch         5134
# Call Center    3530
# Web            2650
# Name: Sales Channel, dtype: int64

# %%
sb.countplot(x="Response",hue="Sales Channel",data=tfile)
plt.show()

# %%
sb.barplot(x="Response",y="Income",data=tfile)
plt.show()

# %%
plt.hist("Income")
plt.show()

# %%
sb.barplot(x="Response",y="Total Claim Amount",data=tfile)
plt.show()

# %%
plt.hist("Total Claim Amount")
plt.show()

# %%
tfile['Total Claim Amount'].value_counts()
# Out:
# 316.800000    232
# 292.800000    220
# 312.000000    216
# 350.400000    210
# 331.200000    204
#              ...
# 366.277224      1
# 585.058877      1
# 741.867506      1
# 266.524820      1
# 378.752580      1
# Name: Total Claim Amount, Length: 6378, dtype: int64

# %%
sb.violinplot(x=tfile['Response'],y=tfile['Total Claim Amount'])

# %%
tfile['Total Claim Amount'].max()
# Out:
# 2893.239678

# %%
sb.violinplot(x=tfile['Response'],y=tfile['Income'])
plt.show()
